# %% [markdown]
# <a href="https://colab.research.google.com/github/yathishgorrela/visualisation-in-R/blob/main/python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **python pandas practice**

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Salaries (1).csv")

# %%
df.head()

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.dtypes

# %%
df.size
# Out:
# 468

# %%
df.columns

# %%
df.values

# %%
df.ndim

# %%
df.shape[0]

# %%
df.shape[1]

# %%
df.describe()

# %%
df.std()

# %%
df1=df.head(50)

# %%
df1.mean()

# %%
df.head(50).mean()
# Out:
# <ipython-input-22-56442511a41d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.head(50).mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
df['phd']
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
df[['phd']]
# Out:
#     phd
# 0    56
# 1    12
# 2    23
# 3    40
# 4    20
# ..  ...
# 73   18
# 74   19
# 75   17
# 76   28
# 77   23
#
# [78 rows x 1 columns]

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.groupby(['rank']).mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df.iloc[0:10,0:4]
# Out:
#         rank discipline  phd  service
# 0       Prof          B   56       49
# 1       Prof          A   12        6
# 2       Prof          A   23       20
# 3       Prof          A   40       31
# 4       Prof          B   20       18
# 5       Prof          A   20       20
# 6  AssocProf          A   20       17
# 7       Prof          A   18       18
# 8       Prof          A   29       19
# 9       Prof          A   51       51

# %%
df.iloc[:,4:6]
# Out:
#        sex  salary
# 0     Male  186960
# 1     Male   93000
# 2     Male  110515
# 3     Male  131205
# 4     Male  104800
# ..     ...     ...
# 73  Female  105450
# 74  Female  104542
# 75  Female  124312
# 76  Female  109954
# 77  Female  109646
#
# [78 rows x 2 columns]

# %%
df.iloc[60:61,:]
# Out:
#         rank discipline  phd  service     sex  salary
# 60  AsstProf          B    3        3  Female   92000

# %%
df.iloc[[0,2],:]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 2  Prof          A   23       20  Male  110515

# %%
df[['phd','salary']].agg(['min','max','mean'])
# Out:
#             phd         salary
# min    1.000000   57800.000000
# max   56.000000  186960.000000
# mean  19.705128  108023.782051

# %% [markdown]
# # New Section
